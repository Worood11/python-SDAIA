# %% [markdown]
# # M4.Ex1: Housing Prices Model (PyCaret)

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M6/exercises/ex1_pycaret_regression.ipynb)

# %% [markdown]
# ## Exercise
#
# Your task is to follow the steps outlined here, and apply them on the **California Housing Dataset** below:
#
# - [**🚀 Regression**](https://pycaret.gitbook.io/docs/get-started/quickstart#regression)
#     - Setup
#     - Compare Models
#     - Analyze Model
#     - Predictions
#     - Save the model

# %% [markdown]
# ## California Housing Prices Dataset
#
#
# Find and download the dataset from Kaggle at [California Housing Dataset](https://www.kaggle.com/datasets/dhirajnirne/california-housing-data).
#
# According to [keras.io](https://keras.io/api/datasets/california_housing/):
#
# > This dataset was obtained from the StatLib repository.
# >
# > It's a continuous regression dataset with 20,640 samples with 8 features each.
# >
# > The target variable is a scalar: the median house value for California districts, in dollars.
# >
# > The 8 input features are the following:
# >
# > - MedInc: median income in block group
# > - HouseAge: median house age in block group
# > - AveRooms: average number of rooms per household
# > - AveBedrms: average number of bedrooms per household
# > - Population: block group population
# > - AveOccup: average number of household members
# > - Latitude: block group latitude
# > - Longitude: block group longitude
# >
# > This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
# >
# > A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surprisingly large values for block groups with few households and many empty houses, such as vacation resorts.

# %% [markdown]
# ### Load the data

# %%
# pd.read_csv("../../../datasets/california_housing.csv").head()
import kagglehub

import pandas as pd
import os
os.environ["OMP_NUM_THREADS"] = "1"
# Download latest version
path = kagglehub.dataset_download("dhirajnirne/california-housing-data")

print("Path to dataset files:", path)


print(os.listdir(path))

file_path = path + "/housing.csv"   # adjust name if different
df = pd.read_csv(file_path)
# Out:
# Path to dataset files: /Users/woroodmup/.cache/kagglehub/datasets/dhirajnirne/california-housing-data/versions/1
# ['housing.csv']

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# **Task**: Your model should learn from this data and be able to predict the median housing price (`median_house_value`) in any district, given all the other metrics.
#
# Please read the above dataset description to understand what the features mean.

# %%
print(df.columns.tolist())
# Out:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'ocean_proximity']

# %%
from pycaret.regression import RegressionExperiment
s = RegressionExperiment()
df_small = df.sample(3000, random_state=42)

s.setup(
    data=df_small,
    target='median_house_value',
    verbose=False,
    session_id=42,
    n_jobs=1
)

# %%
best_model = s.compare_models()
print(best_model)
# Out:
# <style type="text/css">
# #T_d8a15 th {
#   text-align: left;
# }
# #T_d8a15_row0_col0, #T_d8a15_row1_col0, #T_d8a15_row1_col1, #T_d8a15_row1_col2, #T_d8a15_row1_col3, #T_d8a15_row1_col4, #T_d8a15_row1_col5, #T_d8a15_row1_col6, #T_d8a15_row2_col0, #T_d8a15_row2_col1, #T_d8a15_row2_col2, #T_d8a15_row2_col3, #T_d8a15_row2_col4, #T_d8a15_row2_col5, #T_d8a15_row2_col6, #T_d8a15_row3_col0, #T_d8a15_row3_col1, #T_d8a15_row3_col2, #T_d8a15_row3_col3, #T_d8a15_row3_col4, #T_d8a15_row3_col5, #T_d8a15_row3_col6, #T_d8a15_row4_col0, #T_d8a15_row4_col1, #T_d8a15_row4_col2, #T_d8a15_row4_col3, #T_d8a15_row4_col4, #T_d8a15_row4_col5, #T_d8a15_row4_col6, #T_d8a15_row5_col0, #T_d8a15_row5_col1, #T_d8a15_row5_col2, #T_d8a15_row5_col3, #T_d8a15_row5_col4, #T_d8a15_row5_col5, #T_d8a15_row5_col6, #T_d8a15_row6_col0, #T_d8a15_row6_col1, #T_d8a15_row6_col2, #T_d8a15_row6_col3, #T_d8a15_row6_col4, #T_d8a15_row6_col5, #T_d8a15_row6_col6, #T_d8a15_row7_col0, #T_d8a15_row7_col1, #T_d8a15_row7_col2, #T_d8a15_row7_col3, #T_d8a15_row7_col4, #T_d8a15_row7_col5, #T_d8a15_row7_col6, #T_d8a15_row8_col0, #T_d8a15_row8_col1, #T_d8a15_row8_col2, #T_d8a15_row8_col3, #T_d8a15_row8_col4, #T_d8a15_row8_col5, #T_d8a15_row8_col6, #T_d8a15_row9_col0, #T_d8a15_row9_col1, #T_d8a15_row9_col2, #T_d8a15_row9_col3, #T_d8a15_row9_col4, #T_d8a15_row9_col5, #T_d8a15_row9_col6, #T_d8a15_row10_col0, #T_d8a15_row10_col1, #T_d8a15_row10_col2, #T_d8a15_row10_col3, #T_d8a15_row10_col4, #T_d8a15_row10_col5, #T_d8a15_row10_col6, #T_d8a15_row11_col0, #T_d8a15_row11_col1, #T_d8a15_row11_col2, #T_d8a15_row11_col3, #T_d8a15_row11_col4, #T_d8a15_row11_col5, #T_d8a15_row11_col6, #T_d8a15_row12_col0, #T_d8a15_row12_col1, #T_d8a15_row12_col2, #T_d8a15_row12_col3, #T_d8a15_row12_col4, #T_d8a15_row12_col5, #T_d8a15_row12_col6, #T_d8a15_row13_col0, #T_d8a15_row13_col1, #T_d8a15_row13_col2, #T_d8a15_row13_col3, #T_d8a15_row13_col4, #T_d8a15_row13_col5, #T_d8a15_row13_col6, #T_d8a15_row14_col0, #T_d8a15_row14_col1, #T_d8a15_row14_col2, #T_d8a15_row14_col3, #T_d8a15_row14_col4, #T_d8a15_row14_col5, #T_d8a15_row14_col6, #T_d8a15_row15_col0, #T_d8a15_row15_col1, #T_d8a15_row15_col2, #T_d8a15_row15_col3, #T_d8a15_row15_col4, #T_d8a15_row15_col5, #T_d8a15_row15_col6, #T_d8a15_row16_col0, #T_d8a15_row16_col1, #T_d8a15_row16_col2, #T_d8a15_row16_col3, #T_d8a15_row16_col4, #T_d8a15_row16_col5, #T_d8a15_row16_col6, #T_d8a15_row17_col0, #T_d8a15_row17_col1, #T_d8a15_row17_col2, #T_d8a15_row17_col3, #T_d8a15_row17_col4, #T_d8a15_row17_col5, #T_d8a15_row17_col6 {
#   text-align: left;
# }
# #T_d8a15_row0_col1, #T_d8a15_row0_col2, #T_d8a15_row0_col3, #T_d8a15_row0_col4, #T_d8a15_row0_col5, #T_d8a15_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d8a15_row0_col7, #T_d8a15_row1_col7, #T_d8a15_row2_col7, #T_d8a15_row3_col7, #T_d8a15_row4_col7, #T_d8a15_row5_col7, #T_d8a15_row6_col7, #T_d8a15_row7_col7, #T_d8a15_row8_col7, #T_d8a15_row9_col7, #T_d8a15_row10_col7, #T_d8a15_row11_col7, #T_d8a15_row12_col7, #T_d8a15_row13_col7, #T_d8a15_row14_col7, #T_d8a15_row15_col7, #T_d8a15_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d8a15_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d8a15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8a15_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8a15_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d8a15_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d8a15_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d8a15_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d8a15_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d8a15_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d8a15_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8a15_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_d8a15_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d8a15_row0_col1" class="data row0 col1" >39158.6016</td>
#       <td id="T_d8a15_row0_col2" class="data row0 col2" >3339213655.4124</td>
#       <td id="T_d8a15_row0_col3" class="data row0 col3" >57463.7327</td>
#       <td id="T_d8a15_row0_col4" class="data row0 col4" >0.7412</td>
#       <td id="T_d8a15_row0_col5" class="data row0 col5" >0.2848</td>
#       <td id="T_d8a15_row0_col6" class="data row0 col6" >0.2197</td>
#       <td id="T_d8a15_row0_col7" class="data row0 col7" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_d8a15_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d8a15_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_d8a15_row1_col1" class="data row1 col1" >40590.7520</td>
#       <td id="T_d8a15_row1_col2" class="data row1 col2" >3573157535.7118</td>
#       <td id="T_d8a15_row1_col3" class="data row1 col3" >59581.9944</td>
#       <td id="T_d8a15_row1_col4" class="data row1 col4" >0.7234</td>
#       <td id="T_d8a15_row1_col5" class="data row1 col5" >0.2874</td>
#       <td id="T_d8a15_row1_col6" class="data row1 col6" >0.2273</td>
#       <td id="T_d8a15_row1_col7" class="data row1 col7" >0.6800</td>
#     </tr>
#     <tr>
#       <th id="T_d8a15_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_d8a15_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d8a15_row2_col1" class="data row2 col1" >41705.7213</td>
#       <td id="T_d8a15_row2_col2" class="data row2 col2" >3611113459.1561</td>
#       <td id="T_d8a15_row2_col3" class="data row2 col3" >59908.9063</td>
#       <td id="T_d8a15_row2_col4" class="data row2 col4" >0.7210</td>
#       <td id="T_d8a15_row2_col5" class="data row2 col5" >0.2930</td>
#       <td id="T_d8a15_row2_col6" class="data row2 col6" >0.2344</td>
#       <td id="T_d8a15_row2_col7" class="data row2 col7" >0.3010</td>
#     </tr>
#     <tr>
#       <th id="T_d8a15_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_d8a15_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_d8a15_row3_col1" class="data row3 col1" >41913.5645</td>
#       <td id="T_d8a15_row3_col2" class="data row3 col2" >3788975682.0480</td>
#       <td id="T_d8a15_row3_col3" class="data row3 col3" >61284.2815</td>
#       <td id="T_d8a15_row3_col4" class="data row3 col4" >0.7072</td>
#       <td id="T_d8a15_row3_col5" class="data row3 col5" >0.2928</td>
#       <td id="T_d8a15_row3_col6" class="data row3 col6" >0.2342</td>
#       <td id="T_d8a15_row3_col7" class="data row3 col7" >0.3040</td>
#     </tr>
#     <tr>
#       <th id="T_d8a15_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_d8a15_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_d8a15_row4_col1" class="data row4 col1" >51321.8106</td>
#       <td id="T_d8a15_row4_col2" class="data row4 col2" >4993428790.6402</td>
#       <td id="T_d8a15_row4_col3" class="data row4 col3" >70445.3917</td>
#       <td id="T_d8a15_row4_col4" class="data row4 col4" >0.6150</td>
#       <td id="T_d8a15_row4_col5" class="data row4 col5" >0.3886</td>
#       <td id="T_d8a15_row4_col6" class="data row4 col6" >0.2991</td>
#       <td id="T_d8a15_row4_col7" class="data row4 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_d8a15_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_d8a15_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_d8a15_row5_col1" class="data row5 col1" >51316.1066</td>
#       <td id="T_d8a15_row5_col2" class="data row5 col2" >4994016602.8203</td>
#       <td id="T_d8a15_row5_col3" class="data row5 col3" >70446.6636</td>
#       <td id="T_d8a15_row5_col4" class="data row5 col4" >0.6149</td>
#       <td id="T_d8a15_row5_col5" class="data row5 col5" >0.3915</td>
#       <td id="T_d8a15_row5_col6" class="data row5 col6" >0.2988</td>
#       <td id="T_d8a15_row5_
# LGBMRegressor(n_jobs=1, random_state=42)

# %%
predictions = s.predict_model(best_model)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_80a41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80a41_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_80a41_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_80a41_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_80a41_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_80a41_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_80a41_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_80a41_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80a41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80a41_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_80a41_row0_col1" class="data row0 col1" >36181.5556</td>
#       <td id="T_80a41_row0_col2" class="data row0 col2" >2788723052.1439</td>
#       <td id="T_80a41_row0_col3" class="data row0 col3" >52808.3616</td>
#       <td id="T_80a41_row0_col4" class="data row0 col4" >0.7835</td>
#       <td id="T_80a41_row0_col5" class="data row0 col5" >0.2599</td>
#       <td id="T_80a41_row0_col6" class="data row0 col6" >0.2023</td>
#     </tr>
#   </tbody>
# </table>
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5182  -118.250000  33.939999                37.0       1002.0           270.0
# 6769  -118.150002  34.099998                52.0       4325.0           823.0
# 15066 -116.970001  32.790001                19.0       4108.0          1101.0
# 19296 -122.820000  38.400002                40.0       2406.0           423.0
# 19246 -122.730003  38.459999                14.0       4042.0          1298.0
#
#        population  households  median_income ocean_proximity  \
# 5182       1092.0       273.0         1.6333       <1H OCEAN
# 6769       1927.0       795.0         3.9485       <1H OCEAN
# 15066      2971.0      1006.0         1.9893       <1H OCEAN
# 19296      1054.0       426.0         3.8846       <1H OCEAN
# 19246      2323.0      1158.0         2.0651       <1H OCEAN
#
#        median_house_value  prediction_label
# 5182              94500.0      96924.141495
# 6769             419100.0     251999.709759
# 15066            112500.0     119704.680715
# 19296            215900.0     188073.119503
# 19246            135400.0     175539.652789

# %%
s.save_model(best_model, 'housing_price_model')
print("Model saved successfully!")
# Out:
# Transformation Pipeline and Model Successfully Saved
# Model saved successfully!
